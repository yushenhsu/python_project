# %%
import sys
import pandas as pd
from pandasai import PandasAI

print(sys.version)
# Out:
# 3.9.12 (main, Apr  5 2022, 01:53:17)
# [Clang 12.0.0 ]

# %%
pip list
# Out:
# Package                       Version
# ----------------------------- --------------------
# aiohttp                       3.8.1
# aiosignal                     1.2.0
# alabaster                     0.7.12
# altair                        4.2.2
# anaconda-client               1.9.0
# anaconda-navigator            2.1.4
# anaconda-project              0.10.2
# anyio                         3.5.0
# appdirs                       1.4.4
# applaunchservices             0.2.1
# appnope                       0.1.2
# appscript                     1.1.2
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.2
# astor                         0.8.1
# astroid                       2.6.6
# astropy                       5.0.4
# asttokens                     2.0.5
# async-timeout                 4.0.1
# atomicwrites                  1.4.0
# attrs                         21.4.0
# Automat                       20.2.0
# ...

# %%
#鐵達尼測試資料
train_data = pd.read_csv("/Users/yushenhsu/Documents/jupyter/titanic/train.csv")
train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Instantiate a LLM
from pandasai.llm.openai import OpenAI
llm = OpenAI(api_token="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") #ronald api

#查資料
pandas_ai = PandasAI(llm)
pandas_ai.run(train_data, prompt='請告訴我sex類別個有多少筆資料')
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
#查資料
pandas_ai = PandasAI(llm)
pandas_ai.run(train_data, prompt='請告訴我Age最大的是哪筆資料，用dataframe呈現')
# Out:
# You exceeded your current quota, please check your plan and billing details.
# 'Unfortunately, I was not able to answer your question, because of the following error:\n\nYou exceeded your current quota, please check your plan and billing details.\n'

# %%
#匯總畫圖
pandas_ai = PandasAI(llm)
pandas_ai.run(train_data, prompt='請告訴我sex類別個有多少筆資料並用長條圖呈現')
# Out:
# You exceeded your current quota, please check your plan and billing details.
# 'Unfortunately, I was not able to answer your question, because of the following error:\n\nYou exceeded your current quota, please check your plan and billing details.\n'

# %%
#匯總畫圖改顏色
pandas_ai = PandasAI(llm)
pandas_ai.run(train_data, prompt='請告訴我pclass類別個有多少筆資料並用不同顏色長條圖呈現')

# %%
#新增欄位
pandas_ai = PandasAI(llm)
pandas_ai.run(train_data, prompt='請協助新增一個欄位，用age判斷，每10歲為一個群組')
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Age Group
# 0      0         A/5 21171   7.2500   NaN        S     21-30
# 1      0          PC 17599  71.2833   C85        C     31-40
# 2      0  STON/O2. 3101282   7.9250   NaN        S     21-30
# 3      0            113803  53.1000  C123        S     31-40
# ...

# %%
#新增欄位
pandas_ai = PandasAI(llm)
pandas_ai.run(train_data, prompt='請幫我找出欄位name中最長的名字的資料，用dataframe顯示')
# Out:
#      PassengerId  Survived  Pclass  \
# 307          308         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 307  Penasco y Castellana, Mrs. Victor de Satode (M...  female  17.0      1
#
#      Parch    Ticket   Fare Cabin Embarked Age Group
# 307      0  PC 17758  108.9   C65        C     11-20
